# %% [markdown]
# <a href="https://colab.research.google.com/github/nevermind78/Time_series_project/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
lien_data="https://github.com/nevermind78/Time_series_project/raw/main/datasets/air_pollution.csv"

# %%
df =pd.read_csv(lien_data)
df.head()
# Out:
#          date  pollution_today        dew       temp        press     wnd_spd  \
# 0  2010-01-02       145.958333  -8.500000  -5.125000  1024.750000   24.860000
# 1  2010-01-03        78.833333 -10.125000  -8.541667  1022.791667   70.937917
# 2  2010-01-04        31.333333 -20.875000 -11.500000  1029.291667  111.160833
# 3  2010-01-05        42.458333 -24.583333 -14.458333  1033.625000   56.920000
# 4  2010-01-06        56.416667 -23.708333 -12.541667  1033.750000   18.511667
#
#         snow  rain  pollution_yesterday
# 0   0.708333   0.0            10.041667
# 1  14.166667   0.0           145.958333
# 2   0.000000   0.0            78.833333
# 3   0.000000   0.0            31.333333
# 4   0.000000   0.0            42.458333
